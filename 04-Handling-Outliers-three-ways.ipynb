# %% [markdown]
# # Handling Outliers: Three ways

# %%
import numpy as np
import pandas as pd

# %%
# np.random.seed(1)
# data1 = np.random.normal(loc=50, scale=5, size=10_000)

# %%
df = pd.read_csv('wildfires_clean.csv')
df
# Out:
#        fire_size fire_name fire_size_class   stat_cause_descr   latitude  \
# 0           10.0       NaN               C  Missing/Undefined  18.105072
# 1            3.0       NaN               B              Arson  35.038330
# 2           60.0       NaN               C              Arson  34.947800
# 3            1.0    WNA  1               B     Debris Burning  39.641400
# 4            2.0       NaN               B      Miscellaneous  30.700600
# ...          ...       ...             ...                ...        ...
# 55362     6289.0    IMPACT               G  Missing/Undefined  39.180000
# 55363    70868.0     BUTTE               G  Missing/Undefined  38.342719
# 55364     5702.0    WILLOW               G              Arson  37.262607
# 55365     3261.0    BARKER               F      Miscellaneous  40.604300
# 55366    76067.0    VALLEY               G  Missing/Undefined  38.843988
#
#         longitude state disc_clean_date cont_clean_date  discovery_month  ...  \
# ...

# %%
df.columns
# Out:
# Index(['fire_size', 'fire_name', 'fire_size_class', 'stat_cause_descr',
#        'latitude', 'longitude', 'state', 'disc_clean_date', 'cont_clean_date',
#        'discovery_month', 'disc_date_final', 'cont_date_final', 'putout_time',
#        'disc_date_pre', 'disc_pre_year', 'disc_pre_month', 'wstation_usaf',
#        'dstation_m', 'wstation_wban', 'wstation_byear', 'wstation_eyear',
#        'Vegetation', 'fire_mag', 'weather_file', 'Temp_pre_30', 'Temp_pre_15',
#        'Temp_pre_7', 'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7',
#        'Wind_cont', 'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont',
#        'Prec_pre_30', 'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness',
#        'cause_code', 'state_code', 'fire_size_class_code'],
#       dtype='object')

# %%
selected_columns=[ 'fire_size', 'latitude', 'longitude',
       'disc_clean_date', 'cont_clean_date', 'discovery_month',
       'disc_date_final', 'cont_date_final', 'putout_time', 'disc_date_pre',
       'disc_pre_year', 'disc_pre_month', 'wstation_usaf', 'dstation_m',
       'wstation_wban', 'wstation_byear', 'wstation_eyear', 'Vegetation',
       'fire_mag' , 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
       'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
       'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
       'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness']
# selected_columns=df['cause_code', 'state_code', 'fire_size_class_code', 'discovery_month','Vegetation',
#        'fire_mag', 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
#        'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
#        'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
#        'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness']
df1= df.loc[:, selected_columns]

# %%
# select only numeric columns
data = df1.select_dtypes(include=[np.number])

# %%
np.mean(data)
# Out:
# /Users/mayankbansal/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3438: FutureWarning: In a future version, DataFrame.mean(axis=None) will return a scalar mean over the entire DataFrame. To retain the old behavior, use 'frame.mean(axis=0)' or just 'frame.mean()'
#   return mean(axis=axis, dtype=dtype, out=out, **kwargs)
# fire_size           2104.645161
# latitude              36.172866
# longitude            -94.757971
# discovery_month        5.694331
# disc_pre_year       2003.765474
# dstation_m         40256.474678
# wstation_wban      61029.607311
# wstation_byear      1979.341900
# wstation_eyear      2015.480990
# Vegetation            11.066068
# fire_mag               9.414366
# Temp_pre_30           10.688533
# Temp_pre_15           10.800765
# Temp_pre_7            10.907171
# Temp_cont              7.838208
# Wind_pre_30            1.926108
# Wind_pre_15            1.844133
# Wind_pre_7             1.791331
# Wind_cont              1.132284
# ...

# %%
np.std(data)
# Out:
# fire_size          14776.871917
# latitude               6.724287
# longitude             15.878051
# discovery_month        3.024111
# disc_pre_year          6.584829
# dstation_m         25271.853186
# wstation_wban      40830.024814
# wstation_byear        23.372592
# wstation_eyear         6.767790
# Vegetation             5.595669
# fire_mag              26.820121
# Temp_pre_30           10.467484
# Temp_pre_15           10.633707
# Temp_pre_7            10.807887
# Temp_cont             10.565460
# Wind_pre_30            2.106146
# Wind_pre_15            2.122678
# Wind_pre_7             2.139688
# Wind_cont              2.030592
# Hum_pre_30            31.086575
# Hum_pre_15            31.042261
# Hum_pre_7             30.827606
# Hum_cont              31.187356
# Prec_pre_30          112.049186
# Prec_pre_15           56.919996
# Prec_pre_7            31.205045
# Prec_cont             59.756573
# remoteness             0.144863
# dtype: float64

# %% [markdown]
# ## [1] Using Standard Deviation
# [Wikipedia](https://en.wikipedia.org/wiki/Outlier) ![Wikipedia](https://upload.wikimedia.org/wikipedia/commons/thumb/3/3a/Standard_deviation_diagram_micro.svg/500px-Standard_deviation_diagram_micro.svg.png)

# %%
data.dtypes
# Out:
# fire_size          float64
# latitude           float64
# longitude          float64
# discovery_month      int64
# disc_pre_year        int64
# dstation_m         float64
# wstation_wban        int64
# wstation_byear       int64
# wstation_eyear       int64
# Vegetation           int64
# fire_mag           float64
# Temp_pre_30        float64
# Temp_pre_15        float64
# Temp_pre_7         float64
# Temp_cont          float64
# Wind_pre_30        float64
# Wind_pre_15        float64
# Wind_pre_7         float64
# Wind_cont          float64
# Hum_pre_30         float64
# Hum_pre_15         float64
# Hum_pre_7          float64
# Hum_cont           float64
# Prec_pre_30        float64
# Prec_pre_15        float64
# Prec_pre_7         float64
# Prec_cont          float64
# remoteness         float64
# dtype: object

# %%
# data['disc_clean_date'] = pd.to_datetime(data['disc_clean_date'])
# data['cont_clean_date'] = pd.to_datetime(data['cont_clean_date'])
# data['disc_date_final'] = pd.to_datetime(data['disc_date_final'])
# data['cont_date_final'] = pd.to_datetime(data['cont_date_final'])

# %%
#np.random.seed(1)

#data = np.random.normal(loc=50, scale=5, size=10_000)

data_mean, data_std = np.mean(data), np.std(data)

# define outliers as 3 times the SD
cut_off = data_std * 3
lower, upper = data_mean - cut_off, data_mean + cut_off

# identify outliers
outliers = [x for x in data if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))

# remove outliers
outliers_removed = [x for x in data if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bc/g85qk5gx76d3d98tnyp1w9k00000gn/T/ipykernel_64765/2574144420.py in <module>
#      10
#      11 # identify outliers
# ---> 12 outliers = [x for x in data if x < lower or x > upper]
#      13 print('Identified outliers: %d' % len(outliers))
#      14
#
# /var/folders/bc/g85qk5gx76d3d98tnyp1w9k00000gn/T/ipykernel_64765/2574144420.py in <listcomp>(.0)
#      10
#      11 # identify outliers
# ---> 12 outliers = [x for x in data if x < lower or x > upper]
#      13 print('Identified outliers: %d' % len(outliers))
#      14
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      68         other = item_from_zerodim(other)
#      69
# ---> 70         return method(self, other)
#      71
#      72     return new_method
#
# ...

# %% [markdown]
# ## [2] Using Inter-Quartile Range (IQR)

# %%
q25, q75 = np.percentile(data, 25), np.percentile(data, 75)
iqr = q75 - q25
print('Percentiles: 25th=%.3f, 75th=%.3f, IQR=%.3f' % (q25, q75, iqr))

# calculate the outlier cutoff
cut_off = iqr * 1.5
lower, upper = q25 - cut_off, q75 + cut_off

# identify outliers
outliers = [x for x in data if x < lower or x > upper]
print('Identified outliers: %d' % len(outliers))

# remove outliers
outliers_removed = [x for x in data if x >= lower and x <= upper]
print('Non-outlier observations: %d' % len(outliers_removed))
# Out:
# Percentiles: 25th=0.000, 75th=45.950, IQR=45.950
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/bc/g85qk5gx76d3d98tnyp1w9k00000gn/T/ipykernel_64765/3421181460.py in <module>
#       8
#       9 # identify outliers
# ---> 10 outliers = [x for x in data if x < lower or x > upper]
#      11 print('Identified outliers: %d' % len(outliers))
#      12
#
# /var/folders/bc/g85qk5gx76d3d98tnyp1w9k00000gn/T/ipykernel_64765/3421181460.py in <listcomp>(.0)
#       8
#       9 # identify outliers
# ---> 10 outliers = [x for x in data if x < lower or x > upper]
#      11 print('Identified outliers: %d' % len(outliers))
#      12
#
# TypeError: '>' not supported between instances of 'numpy.ndarray' and 'str'

# %% [markdown]
# ## [3] Using a builtin class: `LocalOutlierFactor`

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

df = pd.read_csv('wildfires_clean.csv')
# retrieve the array

selected_columns=[ 'fire_size', 'latitude', 'longitude',
       'disc_clean_date', 'cont_clean_date', 'discovery_month',
       'disc_date_final', 'cont_date_final', 'putout_time', 'disc_date_pre',
       'disc_pre_year', 'disc_pre_month', 'wstation_usaf', 'dstation_m',
       'wstation_wban', 'wstation_byear', 'wstation_eyear', 'Vegetation',
       'fire_mag' , 'Temp_pre_30', 'Temp_pre_15', 'Temp_pre_7',
       'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7', 'Wind_cont',
       'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont', 'Prec_pre_30',
       'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness']
df1= df.loc[:, selected_columns]
# select only numeric columns
df2 = df1.select_dtypes(include=[np.number])

data = df2.values

X, y = data[:, :-1], data[:, -1]
print(X.shape, y.shape)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (55367, 27) (55367,)
# (37095, 27) (18272, 27) (37095,) (18272,)

# %%
df2.head()
# Out:
#    fire_size   latitude   longitude  discovery_month  disc_pre_year  \
# 0       10.0  18.105072  -66.753044                2           2007
# 1        3.0  35.038330  -87.610000               12           2006
# 2       60.0  34.947800  -88.722500                2           2004
# 3        1.0  39.641400 -119.308300                6           2005
# 4        2.0  30.700600  -90.591400                9           1999
#
#      dstation_m  wstation_wban  wstation_byear  wstation_eyear  Vegetation  \
# 0   58917.69716          11603            1945            2018          12
# 1   32665.34327          13896            1978            2020          15
# 2  105122.14950          13896            1978            2020          16
# 3   43433.32978          23185            1942            2020           0
# 4   25940.57409           3908            1987            2016          12
#
#    ...  Wind_cont  Hum_pre_30  Hum_pre_15  Hum_pre_7   Hum_cont  Prec_pre_30  \
# ...

# %% [markdown]
# ### fit the model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

model = LinearRegression()
model.fit(X_train, y_train)

yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.032

# %% [markdown]
# ## Using `LocalOutlierFactor`
# https://scikit-learn.org/stable/modules/generated/sklearn.neighbors.LocalOutlierFactor.html
#
# https://scikit-learn.org/stable/auto_examples/neighbors/plot_lof_outlier_detection.html
#
# https://en.wikipedia.org/wiki/Local_outlier_factor

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import LocalOutlierFactor

df = pd.read_csv('wildfires_clean.csv')

df1 = df.select_dtypes(include=[np.number])
data = df1.values

X, y = data[:, :-1], data[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

print(X_train.shape, y_train.shape)

# identify outliers in the training dataset
lof = LocalOutlierFactor()
yhat = lof.fit_predict(X_train)

# select all rows that are not outliers
mask = yhat != -1

X_train, y_train = X_train[mask, :], y_train[mask]
# summarize the shape of the updated training dataset
print(X_train.shape, y_train.shape)


model = LinearRegression()
model.fit(X_train, y_train)

yhat = model.predict(X_test)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# (37095, 30) (37095,)
# (34278, 30) (34278,)
# MAE: 0.446
