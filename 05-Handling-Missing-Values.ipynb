# %% [markdown]
# # Handling Missing Values
# https://www.kaggle.com/datasets/uciml/pima-indians-diabetes-database

# %%
import pandas as pd

# %%
df = pd.read_csv('wildfires_clean.csv', header=0)
# summarize the dataset
df.head(10)
# Out:
#    fire_size fire_name fire_size_class   stat_cause_descr   latitude  \
# 0       10.0       NaN               C  Missing/Undefined  18.105072
# 1        3.0       NaN               B              Arson  35.038330
# 2       60.0       NaN               C              Arson  34.947800
# 3        1.0    WNA  1               B     Debris Burning  39.641400
# 4        2.0       NaN               B      Miscellaneous  30.700600
# 5        1.0       NaN               B     Debris Burning  32.063900
# 6        5.2       NaN               B     Debris Burning  31.316978
# 7        1.0       NaN               B           Campfire  30.904720
# 8        1.0       NaN               B              Arson  35.900310
# 9        1.0     CRAZY               B      Miscellaneous  48.839400
#
#     longitude state disc_clean_date cont_clean_date  discovery_month  ...  \
# 0  -66.753044    PR       2/11/2007             NaN                2  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55367 entries, 0 to 55366
# Data columns (total 44 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fire_size             55367 non-null  float64
#  1   fire_name             25913 non-null  object
#  2   fire_size_class       55367 non-null  object
#  3   stat_cause_descr      55367 non-null  object
#  4   latitude              55367 non-null  float64
#  5   longitude             55367 non-null  float64
#  6   state                 55367 non-null  object
#  7   disc_clean_date       55367 non-null  object
#  8   cont_clean_date       27477 non-null  object
#  9   discovery_month       55367 non-null  int64
#  10  disc_date_final       28708 non-null  object
#  11  cont_date_final       25632 non-null  object
#  12  putout_time           27477 non-null  object
#  13  disc_date_pre         55367 non-null  object
#  14  disc_pre_year         55367 non-null  int64
# ...

# %%
features = df.columns[1:]
features
# Out:
# Index(['fire_name', 'fire_size_class', 'stat_cause_descr', 'latitude',
#        'longitude', 'state', 'disc_clean_date', 'cont_clean_date',
#        'discovery_month', 'disc_date_final', 'cont_date_final', 'putout_time',
#        'disc_date_pre', 'disc_pre_year', 'disc_pre_month', 'wstation_usaf',
#        'dstation_m', 'wstation_wban', 'wstation_byear', 'wstation_eyear',
#        'Vegetation', 'fire_mag', 'weather_file', 'Temp_pre_30', 'Temp_pre_15',
#        'Temp_pre_7', 'Temp_cont', 'Wind_pre_30', 'Wind_pre_15', 'Wind_pre_7',
#        'Wind_cont', 'Hum_pre_30', 'Hum_pre_15', 'Hum_pre_7', 'Hum_cont',
#        'Prec_pre_30', 'Prec_pre_15', 'Prec_pre_7', 'Prec_cont', 'remoteness',
#        'cause_code', 'state_code', 'fire_size_class_code'],
#       dtype='object')

# %%
num_missing = (df[features] == 0).sum()
# report the results
print(num_missing)
# Out:
# fire_name                   0
# fire_size_class             0
# stat_cause_descr            0
# latitude                    0
# longitude                   0
# state                       0
# disc_clean_date             0
# cont_clean_date             0
# discovery_month             0
# disc_date_final             0
# cont_date_final             0
# putout_time                 0
# disc_date_pre               0
# disc_pre_year               0
# disc_pre_month              0
# wstation_usaf               0
# dstation_m                  0
# wstation_wban               0
# wstation_byear              0
# wstation_eyear              0
# Vegetation               9752
# fire_mag                    0
# weather_file                0
# Temp_pre_30              2557
# Temp_pre_15              3937
# Temp_pre_7               4596
# Temp_cont               16865
# Wind_pre_30              3006
# Wind_pre_15              4386
# Wind_pre_7               5039
# Wind_cont               17094
# ...

# %%
import numpy as np

df[features] = df[features].replace(0, np.nan)
# count the number of nan values in each column
df.isnull().sum()
# Out:
# fire_size                   0
# fire_name               29454
# fire_size_class             0
# stat_cause_descr            0
# latitude                    0
# longitude                   0
# state                       0
# disc_clean_date             0
# cont_clean_date         27890
# discovery_month             0
# disc_date_final         26659
# cont_date_final         29735
# putout_time             27890
# disc_date_pre               0
# disc_pre_year               0
# disc_pre_month              0
# wstation_usaf               0
# dstation_m                  0
# wstation_wban               0
# wstation_byear              0
# wstation_eyear              0
# Vegetation               9752
# fire_mag                    0
# weather_file                0
# Temp_pre_30              2557
# Temp_pre_15              3937
# Temp_pre_7               4596
# Temp_cont               16865
# Wind_pre_30              3006
# Wind_pre_15              4386
# Wind_pre_7               5039
# ...

# %%
df.head(20)
# Out:
#     fire_size           fire_name fire_size_class   stat_cause_descr  \
# 0        10.0                 NaN               C  Missing/Undefined
# 1         3.0                 NaN               B              Arson
# 2        60.0                 NaN               C              Arson
# 3         1.0              WNA  1               B     Debris Burning
# 4         2.0                 NaN               B      Miscellaneous
# 5         1.0                 NaN               B     Debris Burning
# 6         5.2                 NaN               B     Debris Burning
# 7         1.0                 NaN               B           Campfire
# 8         1.0                 NaN               B              Arson
# 9         1.0               CRAZY               B      Miscellaneous
# 10        8.3                 NaN               B     Debris Burning
# 11       37.0    SWR-20150212-008               C              Arson
# 12        1.0                 NaN               B     Debris Burning
# ...

# %%
df.shape
# Out:
# (55367, 44)

# %%
df1=df

# %%
nan_percentages = (df1.isna().sum(axis=1) / len(df1.columns)) * 100
nan_percentages
# Out:
# 0        20.454545
# 1        18.181818
# 2        13.636364
# 3        15.909091
# 4        13.636364
#            ...
# 55362    11.363636
# 55363     2.272727
# 55364    20.454545
# 55365     0.000000
# 55366    11.363636
# Length: 55367, dtype: float64

# %%
#df.dropna(inplace=True)
#(3507, 43)


threshold = 50
df1.drop(nan_percentages[nan_percentages > threshold].index, inplace=True)
df1.shape
# Out:
# (55118, 44)

# %%
df.head(20)
# Out:
#     fire_size           fire_name fire_size_class   stat_cause_descr  \
# 0        10.0                 NaN               C  Missing/Undefined
# 1         3.0                 NaN               B              Arson
# 2        60.0                 NaN               C              Arson
# 3         1.0              WNA  1               B     Debris Burning
# 4         2.0                 NaN               B      Miscellaneous
# 5         1.0                 NaN               B     Debris Burning
# 6         5.2                 NaN               B     Debris Burning
# 7         1.0                 NaN               B           Campfire
# 8         1.0                 NaN               B              Arson
# 9         1.0               CRAZY               B      Miscellaneous
# 10        8.3                 NaN               B     Debris Burning
# 11       37.0    SWR-20150212-008               C              Arson
# 12        1.0                 NaN               B     Debris Burning
# ...
